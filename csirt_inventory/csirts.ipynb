# %%
# Load packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
df = pd.read_csv('csirt-inventory.csv')

# %%
print(df.head())
# Out:
#    Country             Team             Constituency  Sectors  \
# 0  Austria      ACOnet-CERT                     NREN      NaN
# 1  Austria              AEC                     CIIP      NaN
# 2  Austria          CERT.at                 National      NaN
# 3  Austria  FREQUENTIS SIRT  Commercial Organisation      NaN
# 4  Austria  GovCERT Austria               Government      NaN
#
#   EU CSIRTs Network       FIRST          Trusted Introducer
# 0        Not member      Member                  Accredited
# 1            Member      Member  Re-Certification Candidate
# 2            Member      Member                   Certified
# 3               NaN      Member                         NaN
# 4            Member  Not member                  Accredited

# %%
df.columns
# Out:
# Index(['Country', 'Team', 'Constituency', 'Sectors', 'EU CSIRTs Network',
#        'FIRST', 'Trusted Introducer'],
#       dtype='object')

# %%
pivot_table = df.pivot_table(index='Country', columns='Constituency', values='Team', aggfunc='count', fill_value=0)

# Print the pivot table
print(pivot_table)
# Out:
# Constituency       -, Commercial Organisation  CIIP  \
# Country
# Austria                                     0     1
# Belgium                                     0     1
# Bulgaria                                    0     0
# Croatia                                     0     0
# Cyprus                                      0     0
# Czech Republic                              0     0
# Denmark                                     0     0
# Estonia                                     0     0
# European Union                              0     0
# Finland                                     0     0
# France                                      1     1
# Germany                                     0     2
# Greece                                      0     0
# Hungary                                     0     0
# Ireland                                     0     0
# Italy                                       0     2
# Latvia                                      0     0
# ...

# %%
# Print unique values of each column
for col in df.columns:
    print(col, df[col].unique())
# Out:
# Country ['Austria' 'Belgium' 'Bulgaria' 'Croatia' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Estonia' 'European Union' 'Finland' 'France' 'Germany'
#  'Greece' 'Hungary' 'Ireland' 'Italy' 'Latvia' 'Lithuania' 'Luxembourg'
#  'Malta' 'Netherlands (The)' 'Poland' 'Portugal' 'Romania' 'Slovakia'
#  'Slovenia' 'Spain' 'Sweden']
# Team ['ACOnet-CERT' 'AEC' 'CERT.at' 'FREQUENTIS SIRT' 'GovCERT Austria'
#  'R-IT CERT' 'R-IT CSIRT' 'WienCERT' 'milCERT AT' 'sCERT AT' 'BELNET CERT'
#  'CERT.be' 'EATM-CERT' 'EXN-GSOC (BE)' 'KBC Group CERT' 'NATO CSC'
#  'NVISO CSIRT' 'NVISO-CSIRT' 'PXS-CSIRT' 'XMConsulting-CSIRT'
#  'Xameco-CSIRT' 'CERT Bulgaria' 'CERT ZSIS' 'CERT.hr' 'CYNET-CSIRT'
#  'National CSIRT-CY' 'SNIPESEC-CSIRT (CY)' '2CCSIRT' 'AC-CSIRT'
#  'ACTIVE24-CSIRT' 'ALEF-CSIRT' 'ATS-CSIRT' 'AXENTA CSIRT' 'Accenture'
#  'Advantech CZ PSIRT' 'Avast CERT' 'CASABLANCA.CZ-CSIRT' 'CDC AEC'
#  'CDT-CERT' 'CESNET-CERTS' 'CETIN CSIRT' 'CRA CSIRT' 'CS-CSIRT'
# ...

# %%
country_team_counts = df.groupby('Country')['Team'].count()

# Print the country and total team counts
print(country_team_counts)
# Out:
# Country
# Austria              10
# Belgium              11
# Bulgaria              1
# Croatia               2
# Cyprus                3
# Czech Republic       68
# Denmark              19
# Estonia               2
# European Union        4
# Finland               5
# France               57
# Germany              53
# Greece                6
# Hungary               3
# Ireland               3
# Italy                36
# Latvia                2
# Lithuania            13
# Luxembourg           11
# Malta                 3
# Netherlands (The)    28
# Poland               37
# Portugal             38
# Romania              10
# Slovakia             14
# Slovenia              3
# Spain                88
# Sweden               26
# Name: Team, dtype: int64
