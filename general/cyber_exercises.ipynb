# %% [markdown]
# ## The Aim of this workbook is to analyze statiscs of cyber exercises between EU countries under the Permenant Structured Cooperation (PESCO) framework. ##

# %%
# Load packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

# %%
# Set the font
plt.rcParams['font.family'] = 'Times New Roman'

from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Times New Roman']

# %%
# Load data and show it 
df = pd.read_excel('eu_cyberattacks.xlsx')
df
# Out:
#            country NATO Member  International Cooperation  \
# 0          Austria          No                          1
# 1          Belgium         Yes                          1
# 2         Bulgaria         Yes                          1
# 3          Croatia         Yes                          1
# 4           Cyprus         Yes                          1
# 5   Czech Republic         Yes                          1
# 6          Denmark         Yes                          1
# 7          Estonia         Yes                          1
# 8          Finland         Yes                          1
# 9           France         Yes                          1
# 10         Germany         Yes                          1
# 11          Greece         Yes                          1
# 12         Hungary         Yes                          1
# 13         Ireland         Yes                          1
# 14           Italy         Yes                          1
# ...

# %%
# Subset for cyber_exercises
df = df[['country', 'Cyber Exercises under CSDP ']]
df
# Out:
#            country  Cyber Exercises under CSDP
# 0          Austria                            0
# 1          Belgium                            1
# 2         Bulgaria                            1
# 3          Croatia                            1
# 4           Cyprus                            2
# 5   Czech Republic                            1
# 6          Denmark                            0
# 7          Estonia                            4
# 8          Finland                            3
# 9           France                            8
# 10         Germany                            4
# 11          Greece                            2
# 12         Hungary                            2
# 13         Ireland                            0
# 14           Italy                            5
# 15          Latvia                            2
# 16       Lithuania                            1
# 17      Luxembourg                            1
# 18           Malta                            0
# ...

# %%
# Rename the colum 
df.rename(columns={'Cyber Exercises under CSDP ': 'cyber_exercises'}, inplace=True)
df
# Out:
# C:\Users\ester\AppData\Local\Temp\ipykernel_32248\146607658.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Cyber Exercises under CSDP ': 'cyber_exercises'}, inplace=True)
#            country  cyber_exercises
# 0          Austria                0
# 1          Belgium                1
# 2         Bulgaria                1
# 3          Croatia                1
# 4           Cyprus                2
# 5   Czech Republic                1
# 6          Denmark                0
# 7          Estonia                4
# 8          Finland                3
# 9           France                8
# 10         Germany                4
# 11          Greece                2
# 12         Hungary                2
# 13         Ireland                0
# 14           Italy                5
# ...

# %%
# Get the top 7 contributors
df_top7 = df.sort_values(by=['cyber_exercises'], ascending=False).head(7)

# Plot the number of exercises per country as bars
plt.figure(figsize=(15, 10))
plt.bar(df_top7['country'], df_top7['cyber_exercises'], color='blue')

# Title and labels
plt.xlabel('Country')
plt.ylabel('Number of exercises')


# Save the plot as a png file in images folder
plt.savefig('../images/cyber_exercises.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
df_top7
# Out:
#         country  cyber_exercises
# 9        France                8
# 14        Italy                5
# 21     Portugal                4
# 7       Estonia                4
# 10      Germany                4
# 19  Netherlands                3
# 25        Spain                3
